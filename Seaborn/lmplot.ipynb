# %% [markdown]
# # Seaborn lmplot

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
sns.set()
# %matplotlib inline

# %%
tips = sns.load_dataset("tips")

# %%
sns.lmplot(data=tips, x="total_bill", y="tip")

# %% [markdown]
# The confidence interval is dony by bootstrap. Which means we sample with replacement from our datapoints, then we compute linear regression. We do this a number of times, and then we use the farthest ones to draw the confidence interval.

# %%
sns.lmplot(data=tips, x="total_bill", y="tip", hue="smoker")

# %%
sns.lmplot(data=tips, x="total_bill", y="tip", col="smoker")

# %%
sns.lmplot(data=tips, x="total_bill", y="tip", col="smoker", row="sex")

# %%
sns.lmplot(data=tips, x="total_bill", y="tip", col="smoker", row="sex", hue="time")

# %%
sns.lmplot(data=tips, x="size", y="tip")

# %%
sns.lmplot(data=tips, x="size", y="tip", x_jitter=.05) # add jitter to improve readability

# %%
sns.lmplot(data=tips, x="size", y="tip", x_estimator=np.mean) # confidence interwals done by bootstrap

# %%
sns.lmplot(data=tips, x="size", y="tip", x_estimator=np.mean, ci=50)

# %%
sns.lmplot(data=tips, x="size", y="tip", x_estimator=np.mean, ci=50, x_ci=98) # x_ci controls confidence interval for x estimator

# %%
sns.lmplot(data=tips, x="total_bill", y="tip", x_bins=10) # its possible to group continuous data into bins

# %%
anscombe = sns.load_dataset("anscombe")

# %%
sns.lmplot(data=anscombe.query("dataset == 'II'"), x="x", y="y", order=2) # using order 2 polynomial instead of linear regression

# %% [markdown]
# ### robust=True
# This attribute deweights outliers

# %%
sns.lmplot(data=anscombe.query("dataset == 'III'"), x="x", y="y")

# %%
sns.lmplot(data=anscombe.query("dataset == 'III'"), x="x", y="y", robust=True) # using robust=True is computationally expensive
# Out:
# C:\Users\Albert\Anaconda3\lib\site-packages\statsmodels\robust\robust_linear_model.py:284: RuntimeWarning: divide by zero encountered in true_divide
#   self.weights = self.M.weights(wls_results.resid/self.scale)
# C:\Users\Albert\Anaconda3\lib\site-packages\statsmodels\robust\robust_linear_model.py:284: RuntimeWarning: invalid value encountered in true_divide
#   self.weights = self.M.weights(wls_results.resid/self.scale)
# C:\Users\Albert\Anaconda3\lib\site-packages\statsmodels\robust\norms.py:190: RuntimeWarning: invalid value encountered in less_equal
#   return np.less_equal(np.fabs(z), self.t)
# C:\Users\Albert\Anaconda3\lib\site-packages\numpy\linalg\linalg.py:1574: RuntimeWarning: invalid value encountered in greater
#   return (S > tol).sum(axis=-1)
# C:\Users\Albert\Anaconda3\lib\site-packages\numpy\lib\function_base.py:4011: RuntimeWarning: Invalid value encountered in median
#   r = func(a, **kwargs)
# ...

# %%
tips["big_tip"] = (tips.tip / tips.total_bill) > 0.15
sns.lmplot(data=tips, x="total_bill", y="big_tip", y_jitter=.03, logistic=True) # use logistic=True for logistic regression
