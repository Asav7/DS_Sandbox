# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
plt.style.use("ggplot")

# %%
data = pd.read_csv("gpw_d.csv")

# %%
data.head()
# Out:
#          Data  Otwarcie  Najwyzszy  Najnizszy  Zamkniecie   Wolumen
# 0  2010-11-09    36.838     39.197     36.655      39.197  15274883
# 1  2010-11-10    39.197     39.197     37.745      37.745   1841613
# 2  2010-11-12    37.092     38.907     36.292      38.907   2266740
# 3  2010-11-15    38.761     39.051     37.745      38.180    522126
# 4  2010-11-16    37.962     38.108     37.164      37.164    484231

# %%
data["Data"] = pd.to_datetime(data["Data"])

# %%
data.head()
# Out:
#         Data  Otwarcie  Najwyzszy  Najnizszy  Zamkniecie   Wolumen
# 0 2010-11-09    36.838     39.197     36.655      39.197  15274883
# 1 2010-11-10    39.197     39.197     37.745      37.745   1841613
# 2 2010-11-12    37.092     38.907     36.292      38.907   2266740
# 3 2010-11-15    38.761     39.051     37.745      38.180    522126
# 4 2010-11-16    37.962     38.108     37.164      37.164    484231

# %%
since_2017 = data[data["Data"] > pd.datetime(2017,1,1)]

# %%
since_2017.shape
# Out:
# (274, 6)

# %%
lower_43 = since_2017[since_2017["Najnizszy"] < 43.5]
lower_43.shape
# Out:
# (79, 6)

# %%
lower_43_z = since_2017[since_2017["Zamkniecie"] < 43.5]
lower_43_z.shape
# Out:
# (59, 6)

# %%
data_2017 = data[(data["Data"] > pd.datetime(2017, 1, 1)) & (data["Data"] < pd.datetime(2018, 1, 1))]
plt.plot(data_2017["Data"], data_2017["Zamkniecie"])
plt.xticks(rotation="vertical")
# Out:
# (array([ 736361.,  736389.,  736420.,  736450.,  736481.,  736511.,
#          736542.,  736573.,  736603.,  736634.,  736664.]),
#  <a list of 11 Text xticklabel objects>)

# %%
plt.plot(since_2017["Data"], since_2017["Zamkniecie"])
plt.plot(since_2017["Data"], since_2017["Najnizszy"])
plt.xticks(rotation="vertical")
ax = plt.gca()
ax.set_ylim(40)
plt.axhline(y=43, color='grey', linestyle='--')
